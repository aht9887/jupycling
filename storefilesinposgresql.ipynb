// %%
//Rise of Lambda functions
#include <iostream>
#include <algorithm>
int main() {
    int arr[] = { 1, 2, 3, 4, 5 };
    int mul = 5;
    std::for_each(arr, arr + sizeof(arr) / sizeof(int), [&](int x) {
        std::cout<<x<<" ";
        // Can modify the mul inside this lambda function because
        // all outer scope elements has write access here.
            mul = 3;
        });
    std::cout << std::endl;
    std::for_each(arr, arr + sizeof(arr) / sizeof(int), [=](int &x) {
        x= x*mul;
        // Can not modify the mul inside this lambda function because
        // all outer scope elements has read only access here.
        // mul = 9;
        });
    std::cout << std::endl;
    std::for_each(arr, arr + sizeof(arr) / sizeof(int), [](int x) {
        // No access to mul inside this lambda function because
        // all outer scope elements are not visible here.
        //std::cout<<mul<<" ";
        });
    std::cout << std::endl;
}
// Out:
// input_line_13:1:5: error: redefinition of 'main'
// int main() {
//     ^
// input_line_10:1:5: note: previous definition is here
// int main() {
//     ^
// Interpreter Error:

// %%
//Storing Binary Data
// All LargeObject API calls must be within a transaction block
conn.setAutoCommit(false);

// Get the Large Object Manager to perform operations with
LargeObjectManager lobj = ((org.postgresql.PGConnection)conn).getLargeObjectAPI();

// Create a new large object
int oid = lobj.create(LargeObjectManager.READ | LargeObjectManager.WRITE);

// Open the large object for writing
LargeObject obj = lobj.open(oid, LargeObjectManager.WRITE);

// Now open the file
File file = new File("myimage.gif");
FileInputStream fis = new FileInputStream(file);

// Copy the data from the file to the large object
byte buf[] = new byte[2048];
int s, tl = 0;
while ((s = fis.read(buf, 0, 2048)) > 0) {
    obj.write(buf, 0, s);
    tl += s;
}

// Close the large object
obj.close();

// Now insert the row into imageslo
PreparedStatement ps = conn.prepareStatement("INSERT INTO imageslo VALUES (?, ?)");
ps.setString(1, file.getName());
ps.setInt(2, oid);
ps.executeUpdate();
ps.close();
fis.close();
// Out:
// input_line_14:4:1: error: use of undeclared identifier 'conn'
// conn.setAutoCommit(false);
// ^
// input_line_14:6:1: error: unknown type name 'LargeObjectManager'
// LargeObjectManager lobj = ((org.postgresql.PGConnection)conn).getLargeObjectAPI();
// ^
// input_line_14:6:29: error: use of undeclared identifier 'org'
// LargeObjectManager lobj = ((org.postgresql.PGConnection)conn).getLargeObjectAPI();
//                             ^
// input_line_14:8:23: error: use of undeclared identifier 'LargeObjectManager'
// int oid = lobj.create(LargeObjectManager.READ | LargeObjectManager.WRITE);
//                       ^
// input_line_14:8:49: error: use of undeclared identifier 'LargeObjectManager'
// int oid = lobj.create(LargeObjectManager.READ | LargeObjectManager.WRITE);
//                                                 ^
// input_line_14:10:1: error: unknown type name 'LargeObject'
// LargeObject obj = lobj.open(oid, LargeObjectManager.WRITE);
// ^
// input_line_14:10:34: error: use of undeclared identifier 'LargeObjectManager'
// LargeObject obj = lobj.open(oid, LargeObjectManager.WRITE);
//                                  ^
// input_line_14:12:1: error: unknown type name 'File'
// File file = new File("myimage.gif");
// ^
// input_line_14:12:17: error: unknown type name 'File'
// File file = new File("myimage.gif");
//                 ^
// input_line_14:13:1: error: unknown type name 'FileInputStream'
// FileInputStream fis = new FileInputStream(file);
// ^
// input_line_14:13:27: error: unknown type name 'FileInputStream'
// FileInputStream fis = new FileInputStream(file);
//                           ^
// input_line_14:15:1: error: unknown type name 'byte'
// byte buf[] = new byte[2048];
// ^
// input_line_14:15:18: error: unknown type name 'byte'
// byte buf[] = new byte[2048];
//                  ^
// input_line_14:24:1: error: unknown type name 'PreparedStatement'
// PreparedStatement ps = conn.prepareStatement("INSERT INTO imageslo VALUES (?, ?)");
// ^
// input_line_14:24:24: error: use of undeclared identifier 'conn'
// PreparedStatement ps = conn.prepareStatement("INSERT INTO imageslo VALUES (?, ?)");
//                        ^
// Interpreter Error:
